# %%
# !pip install wandb==0.21.1 scikit-learn==1.6.1

# %%
# !wandb login

# %% [markdown]
# ### DATA

# %%
# !uv add pandas
# Out:
# Resolved 126 packages in 108ms
# Installed 2 packages in 409ms
#  + pandas==2.3.3
#  + pytz==2025.2

# %%
import wandb
import pandas as pd
from sklearn.datasets import fetch_california_housing

def upload_raw_dataset():
    """
    Fetches the California Housing dataset, saves it as a CSV,
    and logs it as a W&B Artifact.
    """
    # 1. Initialize a W&B run
    with wandb.init \
     (project="house-price-prediction", job_type="upload-dataset") as run:

        # 2. Fetch data
        housing = fetch_california_housing(as_frame=True)
        df = housing.frame

        # 3. Save data to a local file
        filename = "california_housing_raw.csv"
        df.to_csv(filename, index=False)

        # 4. Create a W&B Artifact
        # We use a descriptive name and the type 'dataset'.
        raw_data_artifact = wandb.Artifact(
            "california-housing-raw",
            type="dataset",
            description="Raw California Housing dataset from scikit-learn.",
            metadata={"source": "scikit-learn.fetch_california_housing"}
        )

        # 5. Add the file to the artifact
        raw_data_artifact.add_file(filename)

        # 6. Log the artifact to W&B
        # This uploads the file and creates the first version, 'v0'.
        run.log_artifact(raw_data_artifact)
        print("Successfully logged raw data artifact.")

upload_raw_dataset()
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from C:\Users\jagan\_netrc.
# wandb: Currently logged in as: jagansairohandevaki (jagansairohandevaki-google) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>C:\Users\jagan\Documents\coding\MLops-DDOS\wandb-expt\wandb\run-20260117_132836-7kg8s2x4</code>
# Syncing run <strong><a href='https://wandb.ai/jagansairohandevaki-google/house-price-prediction/runs/7kg8s2x4' target="_blank">rural-cherry-1</a></strong> to <a href='https://wandb.ai/jagansairohandevaki-google/house-price-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/jagansairohandevaki-google/house-price-prediction' target="_blank">https://wandb.ai/jagansairohandevaki-google/house-price-prediction</a>
#  View run at <a href='https://wandb.ai/jagansairohandevaki-google/house-price-prediction/runs/7kg8s2x4' target="_blank">https://wandb.ai/jagansairohandevaki-google/house-price-prediction/runs/7kg8s2x4</a>
# Successfully logged raw data artifact.
#  View run <strong style="color:#cdcd00">rural-cherry-1</strong> at: <a href='https://wandb.ai/jagansairohandevaki-google/house-price-prediction/runs/7kg8s2x4' target="_blank">https://wandb.ai/jagansairohandevaki-google/house-price-prediction/runs/7kg8s2x4</a><br> View project at: <a href='https://wandb.ai/jagansairohandevaki-google/house-price-prediction' target="_blank">https://wandb.ai/jagansairohandevaki-google/house-price-prediction</a><br>Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260117_132836-7kg8s2x4\logs</code>

# %% [markdown]
# ### TRAIN AND TRACK

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import wandb.sklearn
import joblib

def train_regressor():
    """
    Trains a RandomForestRegressor, logging results and plots to W&B.
    """
    # Default hyperparameters
    def_config = {
        "n_estimators": 100,
        "max_depth": 10,
        "min_samples_leaf": 2,
        "random_state": 42
    }

    # 1. Initialize a W&B run
    with wandb.init \
     (project="house-price-prediction", job_type="training", config=def_config,
      tags=["random-forest", "regression", "housing"]) as run:

        config = wandb.config

        # 2. Use the dataset artifact
        # This will download the artifact and create a lineage link.
        artifact = run.use_artifact('california-housing-raw:latest')
        artifact_dir = artifact.download()
        print(artifact_dir)
        data_path = f"{artifact_dir}/california_housing_raw.csv"
        df = pd.read_csv(data_path)
        print(df.head())

        # 3. Prepare data
        X = df.drop('MedHouseVal', axis=1)
        y = df['MedHouseVal']
        X_train, X_test, y_train, y_test = train_test_split(
                                            X, y, test_size=0.2,
                                            random_state=config.random_state)

        # 4. Train the model
        model = RandomForestRegressor(
            n_estimators=config.n_estimators,
            max_depth=config.max_depth,
            min_samples_leaf=config.min_samples_leaf,
            random_state=config.random_state
        )
        model.fit(X_train, y_train)

        # 5. Evaluate and log metrics
        y_pred = model.predict(X_test)
        mse = mean_squared_error(y_test, y_pred)
        r2 = r2_score(y_test, y_pred)

        wandb.log({
            "mse": mse,
            "r2": r2
        })

        print(f"MSE: {mse:.4f}, R2: {r2:.4f}")

        # 6. Log scikit-learn plots
        # This is a convenience function that generates and logs multiple plots.
        plots = wandb.sklearn.plot_regressor(
            model,
            X_train,
            X_test,
            y_train,
            y_test,
            model_name="RandomForestRegressor"
        )

        wandb.log({"regressor_plots": plots})

        # 7. Save the model file
        model_filename = "rf_regressor.joblib"
        joblib.dump(model, model_filename)

        # 8. Create a model artifact
        model_artifact = wandb.Artifact(
            "house-price-rf-regressor",
            type="model",
            description="A trained RandomForestRegressor for housing data.",
            metadata=dict(run.config) # Link hyperparameters
        )

        # 9. Add the model file to the artifact
        model_artifact.add_file(model_filename)

        # 10. Log the model artifact
        run.log_artifact(model_artifact)

        print("Successfully logged model artifact.")

train_regressor()
# Out:
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>C:\Users\jagan\Documents\coding\MLops-DDOS\wandb-expt\wandb\run-20260117_135842-81e417tv</code>
# Syncing run <strong><a href='https://wandb.ai/jagansairohandevaki-google/house-price-prediction/runs/81e417tv' target="_blank">charmed-sun-2</a></strong> to <a href='https://wandb.ai/jagansairohandevaki-google/house-price-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/jagansairohandevaki-google/house-price-prediction' target="_blank">https://wandb.ai/jagansairohandevaki-google/house-price-prediction</a>
#  View run at <a href='https://wandb.ai/jagansairohandevaki-google/house-price-prediction/runs/81e417tv' target="_blank">https://wandb.ai/jagansairohandevaki-google/house-price-prediction/runs/81e417tv</a>
# wandb:   1 of 1 files downloaded.
# C:\Users\jagan\Documents\coding\MLops-DDOS\wandb-expt\artifacts\california-housing-raw-v0
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422
# MSE: 0.2947, R2: 0.7751
# wandb:
# wandb: Plotting RandomForestRegressor.
# C:\Users\jagan\Documents\coding\MLops-DDOS\wandb-expt\.venv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# wandb: Logged summary metrics.
# wandb: Logged learning curve.
# C:\Users\jagan\Documents\coding\MLops-DDOS\wandb-expt\.venv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# wandb: WARNING using only the first 1000 datapoints to create chart outlier_candidates
# wandb: Logged outlier candidates.
# C:\Users\jagan\Documents\coding\MLops-DDOS\wandb-expt\.venv\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# wandb: WARNING using only the first 100 datapoints to create chart residuals
# wandb: WARNING using only the first 100 datapoints to create chart residuals
# wandb: Logged residuals.
# Successfully logged model artifact.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>mse</td><td>▁</td></tr><tr><td>r2</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>mse</td><td>0.29471</td></tr><tr><td>r2</td><td>0.7751</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">charmed-sun-2</strong> at: <a href='https://wandb.ai/jagansairohandevaki-google/house-price-prediction/runs/81e417tv' target="_blank">https://wandb.ai/jagansairohandevaki-google/house-price-prediction/runs/81e417tv</a><br> View project at: <a href='https://wandb.ai/jagansairohandevaki-google/house-price-prediction' target="_blank">https://wandb.ai/jagansairohandevaki-google/house-price-prediction</a><br>Synced 5 W&B file(s), 4 media file(s), 10 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260117_135842-81e417tv\logs</code>

# %% [markdown]
# ### PULL REGISTERED MODEL

# %%
import wandb
import joblib

run = wandb.init(project="house-price-prediction", job_type="inference")

# Load artifact from model registry
artifact = run.use_artifact("wandb-registry-registry-house-price/Registered-regressors:staging")
artifact_dir = artifact.download()

# Load the model
model = joblib.load(f"{artifact_dir}/rf_regressor.joblib")
# Out:
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">solar-firefly-3</strong> at: <a href='https://wandb.ai/jagansairohandevaki-google/house-price-prediction/runs/8bi8gpcu' target="_blank">https://wandb.ai/jagansairohandevaki-google/house-price-prediction/runs/8bi8gpcu</a><br> View project at: <a href='https://wandb.ai/jagansairohandevaki-google/house-price-prediction' target="_blank">https://wandb.ai/jagansairohandevaki-google/house-price-prediction</a><br>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20260117_140020-8bi8gpcu\logs</code>
# Tracking run with wandb version 0.24.0
# Run data is saved locally in <code>C:\Users\jagan\Documents\coding\MLops-DDOS\wandb-expt\wandb\run-20260117_140122-rsilvbu9</code>
# Syncing run <strong><a href='https://wandb.ai/jagansairohandevaki-google/house-price-prediction/runs/rsilvbu9' target="_blank">splendid-mountain-4</a></strong> to <a href='https://wandb.ai/jagansairohandevaki-google/house-price-prediction' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/jagansairohandevaki-google/house-price-prediction' target="_blank">https://wandb.ai/jagansairohandevaki-google/house-price-prediction</a>
#  View run at <a href='https://wandb.ai/jagansairohandevaki-google/house-price-prediction/runs/rsilvbu9' target="_blank">https://wandb.ai/jagansairohandevaki-google/house-price-prediction/runs/rsilvbu9</a>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\Documents\coding\MLops-DDOS\wandb-expt\.venv\lib\site-packages\wandb\apis\normalize.py:28, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      27 try:
# ---> 28     return func(*args, **kwargs)
#      30 except requests.HTTPError as error:
#
# File ~\Documents\coding\MLops-DDOS\wandb-expt\.venv\lib\site-packages\wandb\apis\public\api.py:1494, in Api._artifact(self, name, type, enable_tracking)
#    1493 path = FullArtifactPath(prefix=entity, project=project, name=artifact_name)
# -> 1494 artifact = Artifact._from_name(
#    1495     path=path,
#    1496     client=self.client,
#    1497     enable_tracking=enable_tracking,
#    1498 )
#    1499 if type is not None and artifact.type != type:
#
# File ~\Documents\coding\MLops-DDOS\wandb-expt\.venv\lib\site-packages\wandb\sdk\artifacts\artifact.py:326, in Artifact._from_name(cls, path, client, enable_tracking)
#     325 if server_supports(client, pb.PROJECT_ARTIFACT_COLLECTION_MEMBERSHIP):
# --> 326     return cls._membership_from_name(path=path, client=client)
#     328 gql_vars = {
#     329     "entity": path.prefix,
#     330     "project": path.project,
#     331     "name": path.name,
#     332     "enableTracking": enable_tracking,
#     333 }
#
# File ~\Documents\coding\MLops-DDOS\wandb-expt\.venv\lib\site-packages\wandb\sdk\artifacts\artifact.py:306, in Artifact._membership_from_name(cls, path, client)
#     305     msg = f"project {path.project!r} not found under entity {path.prefix!r}"
# --> 306     raise ValueError(msg)
#     308 if not (membership := project.artifact_collection_membership):
#
# ValueError: project 'wandb-registry-registry-house-price' not found under entity 'jagansairohandevaki-google-org'
#
# During handling of the above exception, another exception occurred:
#
# CommError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       4 run = wandb.init(project="house-price-prediction", job_type="inference")
#       6 # Load artifact from model registry
# ----> 7 artifact = run.use_artifact("wandb-registry-registry-house-price/Registered-regressors:staging")
#       8 artifact_dir = artifact.download()
#      10 # Load the model
#
# File ~\Documents\coding\MLops-DDOS\wandb-expt\.venv\lib\site-packages\wandb\sdk\wandb_run.py:400, in _log_to_run.<locals>.wrapper(self, *args, **kwargs)
#     397     run_id = self._attach_id
#     399 with wb_logging.log_to_run(run_id):
# --> 400     return func(self, *args, **kwargs)
#
# File ~\Documents\coding\MLops-DDOS\wandb-expt\.venv\lib\site-packages\wandb\sdk\wandb_run.py:458, in _raise_if_finished.<locals>.wrapper_fn(self, *args, **kwargs)
#     455 @functools.wraps(func)
#     456 def wrapper_fn(self: Run, *args: _P.args, **kwargs: _P.kwargs) -> _T:
#     457     if not getattr(self, "_is_finished", False):
# --> 458         return func(self, *args, **kwargs)
#     460     message = (
#     461         f"Run ({self.id}) is finished. The call to"
#     462         f" `{func.__name__}` will be ignored."
#     463         f" Please make sure that you are using an active run."
#     464     )
#     466     raise UsageError(message)
#
# File ~\Documents\coding\MLops-DDOS\wandb-expt\.venv\lib\site-packages\wandb\sdk\wandb_run.py:445, in _attach.<locals>.wrapper(self, *args, **kwargs)
#     442     finally:
#     443         _is_attaching = ""
# --> 445 return func(self, *args, **kwargs)
#
# File ~\Documents\coding\MLops-DDOS\wandb-expt\.venv\lib\site-packages\wandb\sdk\wandb_run.py:3094, in Run.use_artifact(self, artifact_or_name, type, aliases, use_as)
#    3092 name = artifact_or_name
#    3093 public_api = self._public_api()
# -> 3094 artifact = public_api._artifact(type=type, name=name)
#    3095 if type is not None and type != artifact.type:
#    3096     raise ValueError(
#    3097         f"Supplied type {type} does not match type {artifact.type} of artifact {artifact.name}"
#    3098     )
#
# File ~\Documents\coding\MLops-DDOS\wandb-expt\.venv\lib\site-packages\wandb\apis\normalize.py:82, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      80     raise
#      81 else:
# ---> 82     raise CommError(message, err).with_traceback(sys.exc_info()[2])
#
# File ~\Documents\coding\MLops-DDOS\wandb-expt\.venv\lib\site-packages\wandb\apis\normalize.py:28, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      26 message = "Whoa, you found a bug."
#      27 try:
# ---> 28     return func(*args, **kwargs)
#      30 except requests.HTTPError as error:
#      31     errors = parse_backend_error_messages(error.response)
#
# File ~\Documents\coding\MLops-DDOS\wandb-expt\.venv\lib\site-packages\wandb\apis\public\api.py:1494, in Api._artifact(self, name, type, enable_tracking)
#    1489     raise ValueError(
#    1490         "Could not determine entity. Please include the entity as part of the artifact name path."
#    1491     )
#    1493 path = FullArtifactPath(prefix=entity, project=project, name=artifact_name)
# -> 1494 artifact = Artifact._from_name(
#    1495     path=path,
#    1496     client=self.client,
#    1497     enable_tracking=enable_tracking,
#    1498 )
#    1499 if type is not None and artifact.type != type:
#    1500     raise ValueError(
#    1501         f"type {type} specified but this artifact is of type {artifact.type}"
#    1502     )
#
# File ~\Documents\coding\MLops-DDOS\wandb-expt\.venv\lib\site-packages\wandb\sdk\artifacts\artifact.py:326, in Artifact._from_name(cls, path, client, enable_tracking)
#     323 from ._generated import ARTIFACT_BY_NAME_GQL, ArtifactByName
#     325 if server_supports(client, pb.PROJECT_ARTIFACT_COLLECTION_MEMBERSHIP):
# --> 326     return cls._membership_from_name(path=path, client=client)
#     328 gql_vars = {
#     329     "entity": path.prefix,
#     330     "project": path.project,
#     331     "name": path.name,
#     332     "enableTracking": enable_tracking,
#     333 }
#     334 gql_op = gql(ARTIFACT_BY_NAME_GQL)
#
# File ~\Documents\coding\MLops-DDOS\wandb-expt\.venv\lib\site-packages\wandb\sdk\artifacts\artifact.py:306, in Artifact._membership_from_name(cls, path, client)
#     304 if not (project := result.project):
#     305     msg = f"project {path.project!r} not found under entity {path.prefix!r}"
# --> 306     raise ValueError(msg)
#     308 if not (membership := project.artifact_collection_membership):
#     309     entity_project = f"{path.prefix}/{path.project}"
#
# CommError: project 'wandb-registry-registry-house-price' not found under entity 'jagansairohandevaki-google-org'
